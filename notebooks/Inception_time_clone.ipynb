# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !ls
# Out:
# archives				 receptive.py
# classifiers				 requirements.txt
# main.py					 results-inception-128.csv
# pngs					 results-InceptionTime-128.csv
# __pycache__				 results-InceptionTime-85.csv
# README.md				 utils
# receptive_field_remove_non_completed.sh

# %%
# %cd /content/gdrive/MyDrive/Inception_time/InceptionTime/
# Out:
# /content/gdrive/MyDrive/Inception_time/InceptionTime

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Inception_time/InceptionTime

# %%
import sys
sys.path.append("./")
from utils import utils

# %%
from main import *
from utils import *
from classifiers import *

# %%
# !python3 main.py InceptionTime
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file 'main.py': [Errno 107] Transport endpoint is not connected
